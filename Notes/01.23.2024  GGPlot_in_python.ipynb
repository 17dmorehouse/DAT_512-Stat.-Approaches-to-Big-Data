# %% [markdown]
# **Using GGPlot within Python**
#
# HD Sheets,   12/27/2023
#
# GGPlot is the grammar of graphics based tool that many of us like in R
#
# There is a more or less port of this package to Python, so if you are good at using GGPlot, it is available
#
# Using Material from https://realpython.com/ggplot-python/
#
# See also
#
# https://plotnine.readthedocs.io/en/v0.12.4/

# %%
from plotnine.data import economics

economics
# Out:
#           date      pce     pop  psavert  uempmed  unemploy
# 0   1967-07-01    507.4  198712     12.5      4.5      2944
# 1   1967-08-01    510.5  198911     12.5      4.7      2945
# 2   1967-09-01    516.3  199113     11.7      4.6      2958
# 3   1967-10-01    512.9  199311     12.5      4.9      3143
# 4   1967-11-01    518.1  199498     12.5      4.7      3066
# ..         ...      ...     ...      ...      ...       ...
# 569 2014-12-01  12122.0  320201      5.0     12.6      8688
# 570 2015-01-01  12080.8  320367      5.5     13.4      8979
# 571 2015-02-01  12095.9  320534      5.7     13.1      8705
# 572 2015-03-01  12161.5  320707      5.2     12.2      8575
# 573 2015-04-01  12158.9  320887      5.6     11.7      8549
#
# [574 rows x 6 columns]

# %% [markdown]
# date: The month when the data was collected
#
# pce: Personal consumption expenditures (in billions of dollars)
#
# pop: The total population (in thousands)
#
# psavert: The personal savings rate
#
# uempmed: The median duration of unemployment (in weeks)
#
# unemploy: The number of unemployed (in thousands)

# %% [markdown]
# **Question/Action**
#
# What type of object is "economics"?
#
# What are it's member functions?
#
# ```
# # This is formatted as code
# ```

# %%
# ?economics
# Type:            DataFrame

# %%
dir(economics)
# 'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'apply',
#  'applymap',
#  'asfreq',
#  'asof',
#  'assign',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'axes',
#  'backfill',
#  'between_time',
#  'bfill',
#  'bool',
#  'boxplot',
#  'clip',
#  'columns',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'date',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'eval',
#  'ewm',
#  'expanding',
#  'explode',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'flags',
#  'floordiv',
#  'from_dict',
#  'from_records',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'insert',
#  'interpolate',
#  'isetitem',
#  'isin',
#  'isna',
#  'isnull',
#  'items',
#  'iterrows',
#  'itertuples',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lt',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'melt',
#  'memory_usage',
#  'merge',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pad',
#  'pce',
#  'pct_change',
#  'pipe',
#  'pivot',
#  'pivot_table',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'psavert',
#  'quantile',
#  'query',
#  'radd',
#  'rank',
#  'rdiv',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'select_dtypes',
#  'sem',
#  'set_axis',
#  'set_flags',
#  'set_index',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'sort_index',
#  'sort_values',
#  'squeeze',
#  'stack',
#  'std',
#  'style',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_feather',
#  'to_gbq',
#  'to_hdf',
#  'to_html',
#  'to_json',
#  'to_latex',
#  'to_markdown',
#  'to_numpy',
#  'to_orc',
#  'to_parquet',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'to_xml',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'uempmed',
#  'unemploy',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'where',
#  'xs'
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
# ...

# %%
# plotting the population changes over the years

from plotnine import ggplot, aes, geom_line


(
    ggplot(economics)  # What data to use
    + aes(x="date", y="pop")  # What variable to use
    + geom_line()  # Geometric object to use for drawing
)
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# **Question/Action**
#
# Plot unemployed vs population

# %%
(
    ggplot(economics)  # What data to use
    + aes(y="unemploy", x="pop")  # What variable to use
    + geom_line()  # Geometric object to use for drawing
)
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# **The MPG data set and setting up ggplot graphics**
#
# *Data* is the information to use when creating the plot.
#
# *Aesthetics* (aes) provides a mapping between data variables and aesthetic, or graphical, variables used by the underlying drawing system. In the previous section, you mapped the date and pop data variables to the x- and y-axis aesthetic variables.
#
# *Geometric objects* (geoms) defines the type of geometric object to use in the drawing. You can use points, lines, bars, and many others.

# %% [markdown]
# **Optional GGplot components**
#
# **Statistical transformations** specify computations and aggregations to be applied to the data before plotting it.
#
# **Scales** apply some transformation during the mapping from data to aesthetics. For example, sometimes you can use a logarithmic scale to better reflect some aspects of your data.
#
# **Facets** allow you to divide data into groups based on some attributes and then plot each group into a separate panel in the same graphic.
#
# **Coordinates systems** map the position of objects to a 2D graphical location in the plot. For example, you can choose to flip the vertical and horizontal axes if that makes more sense in the visualization you’re building.
#
# **Themes** allows you to control visual properties like colors, fonts, and shapes.

# %%
# here is the mpg data set

from plotnine.data import mpg

# set up the plot and define the aesthetics, note that the axes are set, the variables are show but without a geom, nothing plots

ggplot(mpg) + aes(x="class", y="hwy")
# Out:
# <Figure Size: (640 x 480)>

# %%
# here is a scatterplot using this data

from plotnine import geom_point


ggplot(mpg) + aes(x="class", y="hwy") + geom_point()
# Out:
# <Figure Size: (640 x 480)>

# %%
#here is a barplot version
# note the need to explicitly import each geom

from plotnine import geom_bar

ggplot(mpg) + aes(x="class") + geom_bar()
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# **Aggregate and Transform**

# %%
# Import our example dataset with the levels of Lake Huron 1875–1975
from plotnine.data import huron

huron
# Out:
#     year   level  decade
# 0   1875  580.38    1870
# 1   1876  581.86    1870
# 2   1877  580.97    1870
# 3   1878  580.80    1870
# 4   1879  579.79    1870
# ..   ...     ...     ...
# 93  1968  578.52    1960
# 94  1969  579.74    1960
# 95  1970  579.31    1970
# 96  1971  579.89    1970
# 97  1972  579.96    1970
#
# [98 rows x 3 columns]

# %% [markdown]
# **Group the level measurements into bins**, show the counts per bin (ie basic Histogram)

# %%
from plotnine import stat_bin
ggplot(huron) + aes(x="level") + stat_bin(bins=10) + geom_bar()
# Out:
# <Figure Size: (640 x 480)>

# %%
#Here is an actual histogram

from plotnine import  geom_histogram

ggplot(huron) + aes(x="level") + geom_histogram(bins=10)
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# **Group Data  by Decade**

# %%
from plotnine import geom_boxplot

(
  ggplot(huron)
  + aes(x="factor(decade)", y="level")
  + geom_boxplot()
)
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# **Coordinate Flip**

# %%
from plotnine import coord_flip

ggplot(mpg) + aes(x="class") + geom_bar() + coord_flip()
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# **Faceting**
#
# Group data by some attribute and the plot each group separately

# %%
from plotnine import  facet_grid, labs

# note how labs() is used to set labels in this implementation

(
    ggplot(mpg)
    + facet_grid(facets="year~class")
    + aes(x="displ", y="hwy")
    + labs(
        x="Engine Size",
        y="Miles per Gallon",
        title="Miles per Gallon for Each Year and Vehicle Class",
    )
    + geom_point()
)
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# **Themes**
#
# Remember how Themes could be used to control the format details in ggplot?

# %%
from plotnine import theme_dark

(
    ggplot(mpg)
    + facet_grid(facets="year~class")
    + aes(x="displ", y="hwy")
    + labs(
        x="Engine Size",
        y="Miles per Gallon",
        title="Miles per Gallon for Each Year and Vehicle Class",
    )
    + geom_point()
    + theme_dark()
)
# Out:
# <Figure Size: (640 x 480)>

# %%
from plotnine import theme_xkcd

(
    ggplot(mpg)
    + facet_grid(facets="year~class")
    + aes(x="displ", y="hwy")
    + labs(
        x="Engine Size",
        y="Miles per Gallon",
        title="Miles per Gallon for Each Year and Vehicle Class",
    )
    + geom_point()
    + theme_xkcd()
)
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# ...

# %% [markdown]
# **Question/Action**
#
# Find out where to find the listing of themes in plotnine, and how to create your own custom themes.
#
# Add these links to a text cell below

# %% [markdown]
# https://plotnine.readthedocs.io/en/stable/generated/plotnine.themes.theme.html

# %% [markdown]
# **Question/Action**
#
# Find the description of available datasets in plotnine,   add the link to a text cell below

# %% [markdown]
# https://plotnine.readthedocs.io/en/stable/api.html

# %% [markdown]
# **Exporting a plot image to a file**

# %%
# save the plot to a varialbe

myPlot=(
    ggplot(mpg)
    + facet_grid(facets="year~class")
    + aes(x="displ", y="hwy")
    + labs(
        x="Engine Size",
        y="Miles per Gallon",
        title="Miles per Gallon for Each Year and Vehicle Class",
    )
    + geom_point()
    + theme_xkcd()
)

#Call the member function write to a file

myPlot.save("myplot.png",dpi=600)

#note, if you run this code on Google Colab, it will be save to the local temporary file system on colab
# you can download it from there
# Out:
# C:\Users\dev46\anaconda3\Lib\site-packages\plotnine\ggplot.py:587: PlotnineWarning: Saving 6.4 x 4.8 in image.
# C:\Users\dev46\anaconda3\Lib\site-packages\plotnine\ggplot.py:588: PlotnineWarning: Filename: myplot.png
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'xkcd' not found.
# ...
