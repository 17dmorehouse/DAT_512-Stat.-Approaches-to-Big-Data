# %% [markdown]
# # Multiindexing and Lord of the Rings
#
#
# https://www.kaggle.com/mokosan/lord-of-the-rings-character-data?select=WordsByCharacter.csv
#
# https://towardsdatascience.com/how-to-use-multiindex-in-pandas-to-level-up-your-analysis-aeac7f451fce

# %% [markdown]
# ### Create a multi-indexed data frame a standard style dataframe
#
# This is a table of the number of words spoke by characters in the "Lord of the Rings"
#
# We will load it and look at the starting structure and then convert into a multi-indexed form
#
# Note: Down at the bottom of the file are instructions about how to turn off multi-indexing for both rows (index) and column (columns)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
# load data

infile="/content/drive/MyDrive/Colab Notebooks/Spring 2024/DAT_512-Stat.-Approaches-to-Big-Data/Data/WordsByCharacter.csv"

df = pd.read_csv(infile)

# %% [markdown]
# This loads up as a very standard style of data frame

# %%
df.head()
# Out:
#                          Film                 Chapter  Character    Race  \
# 0  The Fellowship Of The Ring            01: Prologue      Bilbo  Hobbit
# 1  The Fellowship Of The Ring            01: Prologue     Elrond     Elf
# 2  The Fellowship Of The Ring            01: Prologue  Galadriel     Elf
# 3  The Fellowship Of The Ring            01: Prologue     Gollum  Gollum
# 4  The Fellowship Of The Ring  02: Concerning Hobbits      Bilbo  Hobbit
#
#    Words
# 0      4
# 1      5
# 2    460
# 3     20
# 4    214

# %%
df.index.names
# Out:
# FrozenList([None])

# %% [markdown]
# In a frozen list, we cannot set items,but we can look up items with it, or hash it for lookups

# %%
# Make a copy of the original version of the data frame

# This example of using Multiindexing shows a number of interesting ways of using multiindexing
#  I wanted to also see how difficult the multiindexing searches are using using a flat data table
# so I duplicated some multi-index queries using just the standard index and column forms.

df_orig=df.copy()

# %% [markdown]
# Here comes the multi-label on the indexes (rows),  using many of the columns as the multiindex
#
# These columns are all really identifiers or categoricals,
#
# Notice that we specify that an index should be set on the data table
#
# This is an example of a highly composite key, with 4 elements in this case

# %%
multi = df.set_index(['Film', 'Chapter', 'Race', 'Character'])

# %%
multi.head()
# Out:
#                                                                     Words
# Film                       Chapter                Race   Character
# The Fellowship Of The Ring 01: Prologue           Hobbit Bilbo          4
#                                                   Elf    Elrond         5
#                                                          Galadriel    460
#                                                   Gollum Gollum        20
#                            02: Concerning Hobbits Hobbit Bilbo        214

# %% [markdown]
# this operation converted columns to multiindices and removed them from the dataframe

# %%
multi.index.names
# Out:
# FrozenList(['Film', 'Chapter', 'Race', 'Character'])

# %%
multi.index.values[0:10]
# Out:
# array([('The Fellowship Of The Ring', '01: Prologue', 'Hobbit', 'Bilbo'),
#        ('The Fellowship Of The Ring', '01: Prologue', 'Elf', 'Elrond'),
#        ('The Fellowship Of The Ring', '01: Prologue', 'Elf', 'Galadriel'),
#        ('The Fellowship Of The Ring', '01: Prologue', 'Gollum', 'Gollum'),
#        ('The Fellowship Of The Ring', '02: Concerning Hobbits', 'Hobbit', 'Bilbo'),
#        ('The Fellowship Of The Ring', '03: The Shire', 'Hobbit', 'Bilbo'),
#        ('The Fellowship Of The Ring', '03: The Shire', 'Hobbit', 'Frodo'),
#        ('The Fellowship Of The Ring', '03: The Shire', 'Ainur', 'Gandalf'),
#        ('The Fellowship Of The Ring', '03: The Shire', 'Hobbit', 'Hobbit Kids'),
#        ('The Fellowship Of The Ring', '03: The Shire', 'Hobbit', 'Hobbits')],
#       dtype=object)

# %%
#use loc to find specific events,   like Who spoke in the Prologue?

multi.loc[('The Fellowship Of The Ring','01: Prologue'),:]
# Out:
# <ipython-input-9-ecbc07d90195>:3: PerformanceWarning: indexing past lexsort depth may impact performance.
#   multi.loc[('The Fellowship Of The Ring','01: Prologue'),:]
#                   Words
# Race   Character
# Hobbit Bilbo          4
# Elf    Elrond         5
#        Galadriel    460
# Gollum Gollum        20

# %%
# Could we do this without multiindexing?
df_orig[ (df_orig.Chapter=="01: Prologue")]
# Out:
#                          Film       Chapter  Character    Race  Words
# 0  The Fellowship Of The Ring  01: Prologue      Bilbo  Hobbit      4
# 1  The Fellowship Of The Ring  01: Prologue     Elrond     Elf      5
# 2  The Fellowship Of The Ring  01: Prologue  Galadriel     Elf    460
# 3  The Fellowship Of The Ring  01: Prologue     Gollum  Gollum     20

# %% [markdown]
# # notice that in this view the movie and the chapter are not shown,   those are fixed by the index,   all the other indices and values are shown though

# %%
# Who where the three first elves to speak in the movie

multi.loc[("The Fellowship Of The Ring",slice(None),'Elf'),:].head(3)
# Out:
#                                                                   Words
# Film                       Chapter                Race Character
# The Fellowship Of The Ring 01: Prologue           Elf  Elrond         5
#                                                        Galadriel    460
#                            21: Flight To The Ford Elf  Arwen        131

# %%
#note that we needed to skip a level in the hiearchy of the index,  the Chapter,  so slice(None) indicates no index on that axis. all entries are collected

# %%
# How much do Gandalf and Saruman talk in each chapter of the The Two Towers

multi.loc[('The Two Towers',slice(None),slice(None),['Gandalf','Saruman']), :]
# Out:
#                                                                                   Words
# Film           Chapter                                           Race  Character
# The Two Towers 01: The Foundations Of Stone                      Ainur Gandalf       39
#                15: The White Rider                               Ainur Gandalf      298
#                17: The Heir Of Númenor                           Ainur Gandalf      226
#                20: The King Of The Golden Hall                   Ainur Gandalf      151
#                22: Simbelmynë on the Burial Mounds               Ainur Gandalf       28
#                23: The King's Decision                           Ainur Gandalf      165
#                58: Forth Eorlingas                               Ainur Gandalf       21
#                65: The Battle For Middle Earth Is About To Begin Ainur Gandalf       36
#                06: The Burning of the Westfold                   Ainur Saruman      187
#                25: The Ring Of Barahir                           Ainur Saruman       68
#                27: Exodus From Edoras                            Ainur Saruman        4
#                36: Isengard Unleashed                            Ainur Saruman       50

# %%
# how much does Isildur talk in all the films

# the xs option allows use to indicate we want to search the level="Character" index only, so all films + Chapters are included

multi.xs('Isildur', level='Character').sum()
# Out:
# Words    1
# dtype: int64

# %% [markdown]
# # Question/Actions
#
# Answer the following questions using multi-indexing ideas
#
# 1.) Find a list of all the Chapters
#
# 2.) Find the Chapter with the least words spoken by an Ainur
#
# 3.) Which chapter(s) does Treebeard speak in?
#
# 4.) Are there any chapters in which only Sam and/or Frodo speak?

# %%
#Q4)
temp = multi.loc[slice(None), slice(None), slice(None), ["Sam", "Frodo"]]
chapter_names = temp.index.get_level_values(1).unique().tolist()

All_Characters = multi.loc[slice(None), chapter_names, slice(None), slice(None)].index.get_level_values(3).unique().tolist()
Everyone_else = set(All_Characters) - set(["Sam", "Frodo"])

chapters_others_speak = multi.loc[slice(None), chapter_names, slice(None), list(Everyone_else)].index.get_level_values(1).unique().tolist()

chapters_sam_frodo_only = [chapter_name for chapter_name in chapter_names if chapter_name not in chapters_others_speak]
multi.loc[slice(None), chapters_sam_frodo_only, slice(None), slice(None)]
# Out:
#                                                                                                Words
# Film                       Chapter                                           Race   Character
# The Fellowship Of The Ring 11: The Passing Of The Elves                      Hobbit Frodo         43
#                                                                                     Sam           40
# The Two Towers             02: Elven Rope                                    Hobbit Frodo         46
#                                                                                     Sam           97
#                            28: The Forests Of Ithilien                       Hobbit Frodo         81
#                                                                                     Sam           87
# The Return Of The King     63: The Land Of Shadow                            Hobbit Frodo         30
#                                                                                     Sam           56
#                            66: I Can't Carry It For You… But I Can Carry You Hobbit Frodo         44
#                                                                                     Sam           85
#                            72: The End Of All Things                         Hobbit Frodo         37
#                                                                                     Sam           31

# %%
# can we do this in the old school way?
df_orig[df_orig.Character=="Isildur"].Words
# Out:
# 101    1
# Name: Words, dtype: int64

# %%
# How much does each Hobbit talk

# Use a pivot table with the words aggregated across all films for each character,

pivoted = df.pivot_table(index = ['Race','Character'],
                         columns = 'Film',
                         aggfunc = 'sum',
                         margins = True, # total column
                         margins_name = 'All Films',
                         fill_value = 0).sort_index()
order = [('Words', 'The Fellowship Of The Ring'),
         ('Words', 'The Two Towers'),
         ('Words', 'The Return Of The King'),
         ('Words', 'All Films')]
pivoted = pivoted.sort_values(by=('Words', 'All Films'), ascending=False)
pivoted = pivoted.reindex(order, axis=1)
# Out:
# <ipython-input-16-50cad5ffb66f>:5: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pivoted = df.pivot_table(index = ['Race','Character'],
# <ipython-input-16-50cad5ffb66f>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pivoted = df.pivot_table(index = ['Race','Character'],
# <ipython-input-16-50cad5ffb66f>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pivoted = df.pivot_table(index = ['Race','Character'],

# %%
pivoted
# Out:
#                                                 Words                 \
# Film                       The Fellowship Of The Ring The Two Towers
# Race      Character
# All Films                                       11225          11169
# Ainur     Gandalf                                2360            964
# Hobbit    Sam                                     557           1044
# Men       Aragorn                                 920            822
# Hobbit    Frodo                                   967            664
# ...                                               ...            ...
#           Mrs. Bracegirdle                          2              0
# Orc       Mauhur                                    0              2
# Men       Eothain                                   0              2
# Hobbit    Proudfoot                                 1              0
# Men       Isildur                                   1              0
#
#
# Film                       The Return Of The King All Films
# Race      Character
# All Films                                    9575     31969
# Ainur     Gandalf                            1504      4828
# Hobbit    Sam                                 924      2525
# Men       Aragorn                             580      2322
# Hobbit    Frodo                               650      2281
# ...                                           ...       ...
#           Mrs. Bracegirdle                      0         2
# Orc       Mauhur                                0         2
# Men       Eothain                               0         2
# Hobbit    Proudfoot                             0         1
# Men       Isildur                               0         1
#
# [75 rows x 4 columns]

# %% [markdown]
# # Question/Action
#
# Repeat any two questions from the previous question/action using classic dataframe methods.
#
# Which approach seems easier?   Is this a matter of just being more familiar with the classic approach?

# %% [markdown]
# The multi index allowed us the ability to explore and filter the amount of code

# %%
chapters = list(set(df.Chapter))
chapters.sort()
chapters
# Out:
# ['01: Prologue',
#  '01: The Finding Of The Ring',
#  '01: The Foundations Of Stone',
#  '02: Concerning Hobbits',
#  '02: Elven Rope',
#  '02: Journey To The Cross-roads',
#  '03: The Road To Isengard',
#  '03: The Shire',
#  '03: The Taming of Sméagol',
#  '04: The Uruk-Hai',
#  '04: The Voice Of Saruman',
#  '04: Very Old Friends',
#  '05: A Long Expected Party',
#  '05: Return To Edoras',
#  '05: The Three Hunters',
#  '06: Farewell Dear Bilbo',
#  "06: Gollum's Villany",
#  '06: The Burning of the Westfold',
#  "07: Eowyn's Dream",
#  '07: Keep It Secret Keep It Safe',
#  '07: Massacre at the Fords of Isen',
#  '08: The Account of Isildur',
#  '08: The Banishment of Éomer',
#  '08: The Palantir',
#  "09: Arwen's Vision",
#  '09: At The Green Dragon',
#  '09: On The Trail Of The Uruk-Hai',
#  '10: Night Camp At Fangorn',
#  '10: The Reforging Of Narsil',
#  '10: The Shadow Of The Past',
#  '11: Minas Tirith',
#  '11: The Passing Of The Elves',
#  '11: The Riders Of Rohan',
#  '12: Saruman The White',
#  '12: The Decline Of Gondor',
#  '12: The Fate Of Merry And Pippin',
#  '13: A Shortcut To Mushrooms',
#  '13: Cross-roads Of The Fallen King',
#  '13: Treebeard',
#  '14: Buckleberry Ferry',
#  '14: The Deep Breath Before The Plunge',
#  '14: The Passage Of The Marshes',
#  '15: At The Sign of the Prancing Pony',
#  '15: Minas Morgul',
#  '15: The White Rider',
#  "16: Sam's Warning",
#  '16: The Nazgul',
#  '16: The Song Of The Entwives',
#  "17: Pippin's Task",
#  '17: The Heir Of Númenor',
#  '17: The Midgewater Marshes',
#  '18: Osgiliath Invaded',
#  '18: The Black Gate Is Closed',
#  '18: The Spoiling Of Isengard',
#  '19: A Knife In The Dark',
#  '19: Ent Draft',
#  '19: The Lighting Of The Beacons',
#  '20: The Caverns Of Isengard',
#  '20: The King Of The Golden Hall',
#  "20: Theoren's Decision",
#  '21: Flight To The Ford',
#  '21: The Fall of Osgiliath',
#  '21: The Funeral Of Théodred',
#  '22: Rivendell',
#  '22: Simbelmynë on the Burial Mounds',
#  "22: The Wizard's Pupil",
#  '23: Many Meetings',
#  "23: The King's Decision",
#  '23: The Stairs Of Cirith Ungol',
#  '24: Brego',
#  '24: Courage Is The Best Defense',
#  '24: The Fate Of The Ring',
#  '25: Peregrin Of The Tower Guard',
#  '25: The Ring Of Barahir',
#  '25: The Sword That Was Broken',
#  '26: A Daughter Of Kings',
#  '26: Allegiance To Denethor',
#  '26: The Evenstar',
#  '27: Exodus From Edoras',
#  '27: The Council Of Elrond',
#  '27: The Parting Of Sam & Frodo',
#  "28: Gilraen's Memorial",
#  '28: The Forests Of Ithilien',
#  '28: The Sacrifice Of Faramir',
#  "29: Bilbo's Gifts",
#  '29: Gollum and Sméagol ',
#  '29: Marshalling At Dunharrow',
#  '30: Anduril - Flame Of The West',
#  '30: Of Herbs And Stewed Rabbit',
#  '30: The Departure Of The Fellowship',
#  '31: Aragorn Takes The Paths Of The Dead',
#  '31: Dwarf Women',
#  '31: The Ring Goes South',
#  '32: No More Despair',
#  '32: One of the Dúnedain',
#  '32: The Pass Of Caradhras',
#  '33: Dwimoberg ~ The Haunted Mountain',
#  '33: Moria',
#  '33: The Evenstar',
#  '34: A Journey In The Dark',
#  '34: The Muster Of Rohan',
#  '34: The Wolves Of Isengard',
#  "35: Balin's Tomb",
#  "35: Helm's Deep",
#  '35: The Paths Of The Dead',
#  '36: Isengard Unleashed',
#  '36: The Bridge Of Khazad-dûm',
#  '36: The Siege Of Gondor',
#  '37: Lothlorien',
#  '37: The Corsairs Of Umbar',
#  '37: The Grace Of The Valar',
#  "38: Arwen's Fate",
#  '38: Caras Galadhon',
#  "38: Shelob's Lair",
#  "39: Merry's Simple Courage",
#  '39: The Mirror Of Galadriel',
#  '39: The Story Foreseen From Lórien',
#  '40: Grond ~ The Hammer Of The Underworld',
#  '40: The Fighting Uruk-hai',
#  '40: The Windows On The West',
#  '41: Farewell To Lorien',
#  '41: Sons Of The Steward',
#  '41: The Tomb Of The Stewards',
#  '42: Breaking The Gate Of Gondor',
#  '42: The Forbidden Pool',
#  '42: The Great River',
#  "43: Aragorn's Return",
#  '43: Parth Galen',
#  '43: The Choices Of Master Samwise Gamgee',
#  "44: Denethor's Madness",
#  '44: Entmoot',
#  '44: The Breaking Of The Fellowship',
#  '45: The Departure Of Boromir',
#  '45: The Glittering Caves',
#  "45: The Witch King's Hour",
#  '46: The Ride Of The Rohirrim',
#  '46: The Road Goes Ever On…',
#  '46: Where Is The Horse And The Rider',
#  "47: Don't Be Hasty Master Meriadoc!",
#  '47: The Pyre Of Denethor',
#  '48: The Battle Of The Pelennor Fields',
#  '48: The Host Of The Eldar',
#  '49: A Far Green Country',
#  '49: The Battle Of The Hornburg',
#  '50: Old Entish',
#  '50: The Nazgul And His Prey',
#  '51: The Black Ships',
#  '51: The Breach Of The Deeping Wall',
#  '52: Shieldmaiden Of Rohan',
#  '52: The Entmoot Decides',
#  '53: The Retreat To The Hornburg',
#  '53: Victory At Minar Tirith',
#  "54: Master Peregrin's Plan",
#  '54: The Passing Of Theoden',
#  '55: Oaths Fulfilled',
#  '55: Osgiliath',
#  '56: The Houses Of Healing',
#  '56: The Last March Of The Ents',
#  '57: Pippin Looks After Merry',
#  '57: The Nazgûl Attack',
#  '58: Forth Eorlingas',
#  '58: The Tower Of Cirith Ungol',
#  '59: The Flooding Of Isengard',
#  '59: The Last Debate',
#  '60: Aragorn Masters The Palantir',
#  '60: The Tales That Really Mattered…',
#  "61: Fangorn Comes To Helm's Deep",
#  '61: The Captain And The White Lady',
#  '62: In The Company Of Orcs',
#  '62: The Final Tally',
#  '63: Flotsam And Jetsam',
#  '63: The Land Of Shadow',
#  '64: Farewell To Faramir',
#  '64: The Mouth Of Sauron',
#  '65: The Battle For Middle Earth Is About To Begin',
#  '65: The Black Gate Opens',
#  "66: Gollum's Plan",
#  "66: I Can't Carry It For You… But I Can Carry You",
#  '67: The Last Move',
#  '68: Mount Doom',
#  '69: The Eagles Are Coming',
#  '70: The Crack Of Doom',
#  '71: Sauron Defeated',
#  '72: The End Of All Things',
#  '73: The Fellowship Reunited',
#  '74: The Return Of The King',
#  '75: Homeward Bound',
#  '76: The Grey Havens']

# %% [markdown]
# # Question/Action
#
# Try to come up with a question of your own that is easier to answer using multi-indexing

# %% [markdown]
# Who are the character that spoke in the last chapter of the first book?

# %%
Last_Chapter = multi.loc[(['The Fellowship Of The Ring'],slice(None),slice(None),slice(None)),:].tail(1)
Last_Chapter
# Out:
#                                                                         Words
# Film                       Chapter                    Race   Character
# The Fellowship Of The Ring 46: The Road Goes Ever On… Hobbit Sam           50

# %% [markdown]
# # More multiindexing,  Simple examples of setting up and altering a multiindex
#
# "Pandas in Action" Boris Paskhaver
#
# Chapter 7

# %%
addresses = [
            ("8809 Flair Square", "Toddside", "IL", "37206"),
            ("9901 Austin Street", "Toddside", "IL", "37206"),
            ("905 Hogan Quarter", "Franklin", "IL", "37206"),
        ]

# %%
row_index = pd.MultiIndex.from_tuples(
            tuples = addresses,
            names = ["Street", "City", "State", "Zip"]
        )

row_index
# Out:
# MultiIndex([( '8809 Flair Square', 'Toddside', 'IL', '37206'),
#             ('9901 Austin Street', 'Toddside', 'IL', '37206'),
#             ( '905 Hogan Quarter', 'Franklin', 'IL', '37206')],
#            names=['Street', 'City', 'State', 'Zip'])

# %%
column_index = pd.MultiIndex.from_tuples(
             [
                 ("Culture", "Restaurants"),
                 ("Culture", "Museums"),
                 ("Services", "Police"),
                 ("Services", "Schools"),
             ]
         )

column_index
# Out:
# MultiIndex([( 'Culture', 'Restaurants'),
#             ( 'Culture',     'Museums'),
#             ('Services',      'Police'),
#             ('Services',     'Schools')],
#            )

# %%
data = [
            ["C-", "B+", "B-", "A"],
            ["D+", "C", "A", "C+"],
            ["A-", "A", "D+", "F"]
        ]

# %%
neighborhoods=pd.DataFrame(
             data = data, index = row_index, columns = column_index
         )
neighborhoods
# Out:
#                                             Culture         Services
#                                         Restaurants Museums   Police Schools
# Street             City     State Zip
# 8809 Flair Square  Toddside IL    37206          C-      B+       B-       A
# 9901 Austin Street Toddside IL    37206          D+       C        A      C+
# 905 Hogan Quarter  Franklin IL    37206          A-       A       D+       F

# %%
neighborhoods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 3 entries, ('8809 Flair Square', 'Toddside', 'IL', '37206') to ('905 Hogan Quarter', 'Franklin', 'IL', '37206')
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   (Culture, Restaurants)  3 non-null      object
#  1   (Culture, Museums)      3 non-null      object
#  2   (Services, Police)      3 non-null      object
#  3   (Services, Schools)     3 non-null      object
# dtypes: object(4)
# memory usage: 810.0+ bytes

# %%
neighborhoods.index
# Out:
# MultiIndex([( '8809 Flair Square', 'Toddside', 'IL', '37206'),
#             ('9901 Austin Street', 'Toddside', 'IL', '37206'),
#             ( '905 Hogan Quarter', 'Franklin', 'IL', '37206')],
#            names=['Street', 'City', 'State', 'Zip'])

# %%
 neighborhoods.index.names
# Out:
# FrozenList(['Street', 'City', 'State', 'Zip'])

# %%
neighborhoods.columns
# Out:
# MultiIndex([( 'Culture', 'Restaurants'),
#             ( 'Culture',     'Museums'),
#             ('Services',      'Police'),
#             ('Services',     'Schools')],
#            )

# %%
neighborhoods.columns.names = ["Category", "Subcategory"]
neighborhoods.columns.names
# Out:
# FrozenList(['Category', 'Subcategory'])

# %% [markdown]
# Below are a number of examples showing how to manipulate data using multi-index approaches

# %%
 neighborhoods.sort_index()
# Out:
# Category                                    Culture         Services
# Subcategory                             Restaurants Museums   Police Schools
# Street             City     State Zip
# 8809 Flair Square  Toddside IL    37206          C-      B+       B-       A
# 905 Hogan Quarter  Franklin IL    37206          A-       A       D+       F
# 9901 Austin Street Toddside IL    37206          D+       C        A      C+

# %%
 neighborhoods.sort_index(ascending=False)
# Out:
# Category                                    Culture         Services
# Subcategory                             Restaurants Museums   Police Schools
# Street             City     State Zip
# 9901 Austin Street Toddside IL    37206          D+       C        A      C+
# 905 Hogan Quarter  Franklin IL    37206          A-       A       D+       F
# 8809 Flair Square  Toddside IL    37206          C-      B+       B-       A

# %%
neighborhoods.sort_index(ascending = [True, False, True])
# Out:
# Category                                    Culture         Services
# Subcategory                             Restaurants Museums   Police Schools
# Street             City     State Zip
# 8809 Flair Square  Toddside IL    37206          C-      B+       B-       A
# 905 Hogan Quarter  Franklin IL    37206          A-       A       D+       F
# 9901 Austin Street Toddside IL    37206          D+       C        A      C+

# %%
neighborhoods["Services"]
# Out:
# Subcategory                             Police Schools
# Street             City     State Zip
# 8809 Flair Square  Toddside IL    37206     B-       A
# 9901 Austin Street Toddside IL    37206      A      C+
# 905 Hogan Quarter  Franklin IL    37206     D+       F

# %%
neighborhoods[("Services", "Schools")]
# Out:
# Street              City      State  Zip
# 8809 Flair Square   Toddside  IL     37206     A
# 9901 Austin Street  Toddside  IL     37206    C+
# 905 Hogan Quarter   Franklin  IL     37206     F
# Name: (Services, Schools), dtype: object

# %%
neighborhoods[[("Services", "Schools"), ("Culture", "Museums")]]
# Out:
# Category                                Services Culture
# Subcategory                              Schools Museums
# Street             City     State Zip
# 8809 Flair Square  Toddside IL    37206        A      B+
# 9901 Austin Street Toddside IL    37206       C+       C
# 905 Hogan Quarter  Franklin IL    37206        F       A

# %%
neighborhoods.xs(key="Franklin",level="City")
# Out:
# Category                          Culture         Services
# Subcategory                   Restaurants Museums   Police Schools
# Street            State Zip
# 905 Hogan Quarter IL    37206          A-       A       D+       F

# %%
neighborhoods.xs(axis = "columns", key = "Museums", level = "Subcategory").head()
# Out:
# Category                                Culture
# Street             City     State Zip
# 8809 Flair Square  Toddside IL    37206      B+
# 9901 Austin Street Toddside IL    37206       C
# 905 Hogan Quarter  Franklin IL    37206       A

# %%
# reordering indices
new_order=["City","State","Zip","Street"]
neighborhoods.reorder_levels(order=new_order)
# Out:
# Category                                    Culture         Services
# Subcategory                             Restaurants Museums   Police Schools
# City     State Zip   Street
# Toddside IL    37206 8809 Flair Square           C-      B+       B-       A
#                      9901 Austin Street          D+       C        A      C+
# Franklin IL    37206 905 Hogan Quarter           A-       A       D+       F

# %%
neighborhoods.reset_index()
# Out:
# Category                 Street      City State    Zip     Culture          \
# Subcategory                                            Restaurants Museums
# 0             8809 Flair Square  Toddside    IL  37206          C-      B+
# 1            9901 Austin Street  Toddside    IL  37206          D+       C
# 2             905 Hogan Quarter  Franklin    IL  37206          A-       A
#
# Category    Services
# Subcategory   Police Schools
# 0                 B-       A
# 1                  A      C+
# 2                 D+       F

# %%
 neighborhoods.reset_index(col_level = 1)
# Out:
# Category                                                   Culture          \
# Subcategory              Street      City State    Zip Restaurants Museums
# 0             8809 Flair Square  Toddside    IL  37206          C-      B+
# 1            9901 Austin Street  Toddside    IL  37206          D+       C
# 2             905 Hogan Quarter  Franklin    IL  37206          A-       A
#
# Category    Services
# Subcategory   Police Schools
# 0                 B-       A
# 1                  A      C+
# 2                 D+       F

# %% [markdown]
# # Question/Action
#
# Which approach or tactic used with the street data seems most interesting, unusual or productive?
#
# Apply this to the Lord of the Rings data,  making up your own question.

# %% [markdown]
# I think the tactic was interesting because you can compare between the different groups in the citiest

# %%
new_order = ['Character', 'Race', 'Character', 'Film']
multi.reorder_levels(order=new_order).sort_index()
# Out:
#                                                          Words
# Character  Race   Character  Film
# Aragorn    Men    Aragorn    The Fellowship Of The Ring     76
#                              The Fellowship Of The Ring     96
#                              The Fellowship Of The Ring     33
#                              The Fellowship Of The Ring     53
#                              The Fellowship Of The Ring     48
# ...                                                        ...
# Wild Man   Men    Wild Man   The Two Towers                 11
# Witch King Nazgul Witch King The Return Of The King         21
#                              The Return Of The King         24
#                              The Return Of The King         13
#                              The Return Of The King          9
#
# [731 rows x 1 columns]

# %%
multi.
# Out:
#                                                                     Words
# Film                       Chapter                Race   Character
# The Fellowship Of The Ring 01: Prologue           Hobbit Bilbo          4
#                                                   Elf    Elrond         5
#                                                          Galadriel    460
#                                                   Gollum Gollum        20
#                            02: Concerning Hobbits Hobbit Bilbo        214
# ...                                                                   ...
# The Return Of The King     76: The Grey Havens    Elf    Elrond         6
#                                                   Hobbit Frodo        132
#                                                   Elf    Galadriel     17
#                                                   Ainur  Gandalf       42
#                                                   Hobbit Sam           14
#
# [731 rows x 1 columns]
